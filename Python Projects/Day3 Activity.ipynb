# %%
#1.	Write a Python program to test if a given page is found or not on the server.

import requests as req
url = 'https://en.wikipedia.org/wiki/Main_Page'
response = req.get(url)
print(response)
# Out:
# <Response [200]>

# %%
#Write a Python program to extract and display all the header tags from en.wikipedia.org/wiki/Main_Page
import requests as req
url = 'https://en.wikipedia.org/wiki/Main_Page'
response = req.get(url)
print(response.headers)
print(response.request.headers)
# Out:
# {'date': 'Thu, 13 Mar 2025 15:44:15 GMT', 'server': 'mw-web.codfw.main-75dbb796cf-tbkdj', 'x-content-type-options': 'nosniff', 'content-language': 'en', 'accept-ch': '', 'vary': 'Accept-Encoding,Cookie,Authorization', 'last-modified': 'Thu, 13 Mar 2025 15:44:02 GMT', 'content-type': 'text/html; charset=UTF-8', 'content-encoding': 'gzip', 'age': '2542', 'x-cache': 'cp4042 miss, cp4042 hit/2188', 'x-cache-status': 'hit-front', 'server-timing': 'cache;desc="hit-front", host;desc="cp4042"', 'strict-transport-security': 'max-age=106384710; includeSubDomains; preload', 'report-to': '{ "group": "wm_nel", "max_age": 604800, "endpoints": [{ "url": "https://intake-logging.wikimedia.org/v1/events?stream=w3c.reportingapi.network_error&schema_uri=/w3c/reportingapi/network_error/1.0.0" }] }', 'nel': '{ "report_to": "wm_nel", "max_age": 604800, "failure_fraction": 0.05, "success_fraction": 0.0}', 'set-cookie': 'WMF-Last-Access=13-Mar-2025;Path=/;HttpOnly;secure;Expires=Mon, 14 Apr 2025 12:00:00 GMT
# ...

# %%
#3.	Write a Python program to get 90 days of visits broken down by browser for all sites on data.gov. 

response = req.get('https://analytics.usa.gov/data/live/browsers.json')
data = response.json()
browser_data = data['totals']['by_browser']
print("30 Days of Visits by Browser for All Sites:")
for browser, visits in browser_data.items():
    print(f"{browser}: {visits} visits")
# Out:
# 30 Days of Visits by Browser for All Sites:
# Chrome: 21336023 visits
# Safari: 9735069 visits
# Edge: 5806156 visits
# Firefox: 1169889 visits
# Internet Explorer: 753206 visits
# Android Webview: 339467 visits
# Samsung Internet: 325121 visits
# Safari (in-app): 283750 visits
# Opera: 144948 visits
# Amazon Silk: 38264 visits
# YaBrowser: 18521 visits
# Mozilla Compatible Agent: 16798 visits
# Whale Browser: 6193 visits
# UC Browser: 944 visits
# Aloha Browser: 335 visits
# PaleMoon: 255 visits
# Meta Quest Browser: 251 visits
# DuckDuckGo Browser: 227 visits
# Phoenix Browser: 219 visits
# Opera Mini: 219 visits
# Android Runtime: 135 visits
# Android Browser: 131 visits
# Vivaldi: 125 visits
# Seznam: 109 visits
# SeaMonkey: 82 visits
# Iron: 66 visits
# Mozilla: 47 visits
# Maxthon: 33 visits
# Waterfox: 22 visits
# Nintendo Browser: 7 visits
# Puffin: 7 visits

# %%
#4.	Write a Python program to extract and display all the image links from en.wikipedia.org/wiki/Peter_Jeffrey_(RAAF_officer)

import requests
from bs4 import BeautifulSoup

url = "https://en.wikipedia.org/wiki/Peter_Jeffrey_(RAAF_officer)"
response = requests.get(url)

if response.status_code == 200:
    soup = BeautifulSoup(response.content, 'html.parser')
    images = soup.find_all('img')

    for img in images:
        img_url = img.get('src')
        if img_url.startswith('//'):
            img_url = 'https:' + img_url
        print(img_url)
else:
    print(f"Failed to retrieve the page. Status code: {response.status_code}")
# Out:
# /static/images/icons/wikipedia.png
# /static/images/mobile/copyright/wikipedia-wordmark-en.svg
# /static/images/mobile/copyright/wikipedia-tagline-en.svg
# https://upload.wikimedia.org/wikipedia/en/thumb/e/e7/Cscr-featured.svg/20px-Cscr-featured.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/NlaJeffrey1942-43.jpg/220px-NlaJeffrey1942-43.jpg
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/c5/008315JeffreyTurnbull1941.jpg/260px-008315JeffreyTurnbull1941.jpg
# https://upload.wikimedia.org/wikipedia/commons/e/ea/021807CameronJeffrey1941.jpg
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/92/AC0072JeffreyTruscottKittyhawks1942.jpg/280px-AC0072JeffreyTruscottKittyhawks1942.jpg
# https://upload.wikimedia.org/wikipedia/commons/thumb/2/26/VIC1689Jeffrey1945.jpg/280px-VIC1689Jeffrey1945.jpg
# https://upload.wikimedia.org/wikipedia/en/thumb/4/4a/Commons-logo.svg/30px-Commons-logo.svg.png
# ...

# %%
#5.	Write a Python program to get the number of people visiting a U.S. government website right now. Source: https://analytics.usa.gov/data/live/realtime.json

import requests
url = "https://analytics.usa.gov/data/live/realtime.json"

response = requests.get(url)
if response.status_code == 200:
    data = response.json()
visits = data['totals']['activeUsers']
print(f"Total number of people visiting a U.S. government website right now: {visits}")
# Out:
# Total number of people visiting a U.S. government website right now: 1628869

# %%
#6.	Write a Python program to get the number of followers of a given twitter account. Choose any twitter account of your favorite celebrity

# %%
#7.	Write a Python program to get the number of followers of a given twitter account.

# %%
#8.	Write a Python program to display the contains of different attributes like different attributes like status_code, 
# headers, url, history, encoding, reason, cookies, elapsed, request and content of a specified resource. 
import requests
import pandas as pd
url = "https://analytics.usa.gov/data/live/realtime.json"

response = requests.get(url)
# (response.headers)
# dict = {"Status code":response.status_code, "Url":response.url,  "History":response.history,
#          "Encoding":response.encoding, "Reason":response.reason, "Cookies":response.cookies, "elapsed":response.elapsed,
#          "Request":response.request}
# dict2 = {"Headers":[response.headers],"Content":[response.content] }
# df = pd.DataFrame(dict)
# df2 = pd.DataFrame(dict2)
# print(df)
# print(df2)
print(f"Status code: {response.status_code}")
print(f"Headers: {response.headers}")
print(f"Url: {response.url}")
print(f"History: {response.history}")
print(f"Encoding: {response.encoding}")
print(f"Reason: {response.reason}")
print(f"Cookies: {response.cookies}")
print(f"elapsed: {response.elapsed}")
print(f"request: {response.request}")
print(f"content: {response.content}")
# Out:
# Status code: 200
# ...

# %%
pip install BeautifulSoup4
# Out:
# ...
#
# ...

# %%
#9.	Write a Python program to extract h1 tag from example.com.
import requests as req
from bs4 import BeautifulSoup

url = 'https://en.wikipedia.org/wiki/Main_Page'
response = req.get(url)
response.content

if response.status_code == 200:
    soup = BeautifulSoup(response.content, 'html.parser')
    h1Tag = soup.find('h1')
else:
    print('Page not found')
h1Tag.text
# Out:
# <h1 class="firstHeading mw-first-heading" id="firstHeading" style="display: none"><span class="mw-page-title-main">Main Page</span></h1>

# %%
#10. Write a Python program to get the number of datasets currently listed on data.gov.
url="https://data.gov/"
response = req.get(url)
data = response.content
if response.status_code == 200:
    soup = BeautifulSoup(response.content, 'html.parser')
    h4Tag = soup.find('div', class_="hero__dataset-count" )

# h4Tag.text
# dataset = h4Tag.text.replace('\n', '').replace('      ', ' ').strip()
# dataset
list0 = h4Tag.text.strip().split('\n')[0]
print("Datasets Availaible", list0)
# Out:
# Datasets Availaible 309,294

# %%
response = req.get("https://catalog.data.gov/api/3/action/package_search", params={"rows":0})
data = response.json()
data
dataset_count = data["result"]["count"]
print(dataset_count)
# Out:
# {'help': 'https://catalog.data.gov/api/3/action/help_show?name=package_search',
#  'success': True,
#  'result': {'count': 309299,
#   'facets': {},
#   'results': [],
#   'sort': 'views_recent desc',
#   'search_facets': {}}}
