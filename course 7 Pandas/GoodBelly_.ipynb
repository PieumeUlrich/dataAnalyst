# %%
# %pip install pandas
# %pip install numpy
# %pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

# %%
# path='C:\\Users\\LENOVO\\Desktop\\NPOWER Materials\\Vancouver resources\\Course 7\\Week 1\GoodBelly-DataSet-Regression.xlsx'
df=pd.read_excel("GoodBelly-DataSet.xlsx", 'Real Data')
df.head(20)
# Out:
#          Date Region                    Store  Units Sold  \
# 0  2010-05-04     FL  Biscayne (aka Aventura)  150.702088
# 1  2010-05-11     FL  Biscayne (aka Aventura)  197.403797
# 2  2010-05-18     FL  Biscayne (aka Aventura)  235.106172
# 3  2010-05-25     FL  Biscayne (aka Aventura)  226.692427
# 4  2010-06-01     FL  Biscayne (aka Aventura)  257.688151
# 5  2010-06-08     FL  Biscayne (aka Aventura)  132.957190
# 6  2010-06-15     FL  Biscayne (aka Aventura)  221.889969
# 7  2010-06-22     FL  Biscayne (aka Aventura)  245.881356
# 8  2010-06-29     FL  Biscayne (aka Aventura)  156.102535
# 9  2010-07-06     FL  Biscayne (aka Aventura)  200.103966
# 10 2010-07-13     FL  Biscayne (aka Aventura)  128.396003
# 11 2010-05-04     FL               Boca Raton  142.778210
# 12 2010-05-11     FL               Boca Raton  237.544554
# 13 2010-05-18     FL               Boca Raton  141.533297
# 14 2010-05-25     FL               Boca Raton  158.073949
# ...

# %%
# 1. Find how many records this data frame has;
len(df)
# Out:
# 1386

# %%
# 2. How many elements are there?
print("Number of elements:")
df.size
# Out:
# Number of elements:
# 16632

# %%
# 3. What are the column names?
df.columns
# Out:
# Index(['Date', 'Region', 'Store', 'Units Sold', 'Average Retail Price',
#        'Sales Rep', 'Endcap', 'Demo', 'Demo1-3', 'Demo4-5', 'Natural',
#        'Fitness'],
#       dtype='object')

# %%
# 4. What types of columns do we have in this dataframe?
df.dtypes
# Out:
# Date                    datetime64[ns]
# Region                          object
# Store                           object
# Units Sold                     float64
# Average Retail Price           float64
# Sales Rep                        int64
# Endcap                           int64
# Demo                             int64
# Demo1-3                          int64
# Demo4-5                          int64
# Natural                          int64
# Fitness                          int64
# dtype: object

# %%
# 5. Give the summary for thenumeric columns in the dataset
df.describe()
# Out:
#                       Date   Units Sold  Average Retail Price    Sales Rep  \
# count                 1386  1386.000000           1386.000000  1386.000000
# mean   2010-06-08 00:00:00   253.820718              4.107093     0.549784
# min    2010-05-04 00:00:00    47.559852              2.889286     0.000000
# 25%    2010-05-18 00:00:00   189.995471              3.775714     0.000000
# 50%    2010-06-08 00:00:00   236.735266              4.096667     1.000000
# 75%    2010-06-29 00:00:00   295.804391              4.425067     1.000000
# max    2010-07-13 00:00:00  1041.200256              6.251538     1.000000
# std                    NaN   110.998731              0.463828     0.497695
#
#             Endcap         Demo      Demo1-3      Demo4-5      Natural  \
# count  1386.000000  1386.000000  1386.000000  1386.000000  1386.000000
# mean      0.038240     0.058442     0.156566     0.075758     1.448773
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# ...

# %%
# 6. Calculate standard deviation for all numeric columns;
df.iloc[:,3:].std(ddof=0)
# Out:
# Units Sold              110.958681
# Average Retail Price      0.463661
# Sales Rep                 0.497515
# Endcap                    0.191774
# Demo                      0.234577
# Demo1-3                   0.363391
# Demo4-5                   0.264610
# Natural                   0.974740
# Fitness                   1.592215
# dtype: float64

# %%
# 7. What are the mean values of the first 50 records in the dataset? Hint:
# usehead() method to subset the first 50 records and then calculate the
# mean

df.head(50).iloc[:,3:].mean()
# Out:
# Units Sold              186.280727
# Average Retail Price      4.128036
# Sales Rep                 0.000000
# Endcap                    0.100000
# Demo                      0.000000
# Demo1-3                   0.000000
# Demo4-5                   0.040000
# Natural                   1.300000
# Fitness                   1.560000
# dtype: float64
